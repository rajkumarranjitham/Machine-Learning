# %%
import pickle #importing library of pickel

# %%
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb'))#loading from file by reading binary and assigning it to loaded_model variable.
result=loaded_model.predict([[0]])#passing the input x to the predict method of loaded_model and assigning the result to the variable result.
# Out:
# C:\Users\Diwali 6\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result#viewing the result
# Out:
# array([[26777.3913412]])
