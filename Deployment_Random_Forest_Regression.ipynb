# %%
import pickle
model=pickle.load(open("random_forest_regressor_model.sav",'rb'))
result=model.predict([[15505.73,127382.30,35534.17,0,1]])
result
# Out:
# C:\Users\Diwali 6\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([68609.5841])
